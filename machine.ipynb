# %% [markdown]
# <a href="https://colab.research.google.com/github/r2x4/aprendiendo_machine/blob/main/machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
#
# ----
# # <center><font color="#615FFF" size="8"> Practice Machine Learning </font></center>
# ----

# %%
# llamar datos
import pandas as pd

datos = pd.read_csv('/content/realistic_drug_labels_side_effects.csv')

# %%
datos.shape
# Out:
# (1436, 15)

# %%
datos.sample(4)
# Out:
#          drug_name          manufacturer  approval_year     drug_class  \
# 1181  Rivacillin18  Moderna Therapeutics           1992      Analgesic
# 669     Loxozole34     Johnson & Johnson           2010     Antibiotic
# 800   Amoxdipine18              Bayer AG           1999     Antifungal
# 44      Cefzepam73  Moderna Therapeutics           1996  Antihistamine
#
#                indications                  side_effects  dosage_mg  \
# 1181      Viral infections                      Diarrhea        420
# 669            Pain relief                      Diarrhea        850
# 800   Bacterial infections  Fatigue, Insomnia, Dizziness         10
# 44    Depression treatment                          Rash        380
#
#      administration_route contraindications                     warnings  \
# 1181              Topical            Asthma  Do not discontinue abruptly
# 669           Intravenous     Heart disease      Avoid sunlight exposure
# 800                Rectal            Asthma         May affect fertility
# 44             Sublingual            Asthma         May cause drowsiness
#
#       price_usd batch_number expiry_date side_effect_severity approval_status
# 1181      88.17      bf360aw  2028-01-30               Severe        Approved
# 669      452.22      rR735JB  2026-02-04                 Mild         Pending
# 800      408.63      NS778ns  2028-05-17             Moderate        Approved
# 44       157.70      oh442Uk  2026-08-05               Severe        Approved

# %%
datos.columns
# Out:
# Index(['drug_name', 'manufacturer', 'approval_year', 'drug_class',
#        'indications', 'side_effects', 'dosage_mg', 'administration_route',
#        'contraindications', 'warnings', 'price_usd', 'batch_number',
#        'expiry_date', 'side_effect_severity', 'approval_status'],
#       dtype='object')

# %%
# renombrar la columnas

datos.columns = [
    "nombre_medicamento",
    "fabricante",
    "año_aprobación",
    "clase_medicamento",
    "indicaciones",
    "efectos_secundarios",
    "dosis_mg",
    "vía_administración",
    "contraindicaciones",
    "advertencias",
    "precio_usd",
    "número_lote",
    "fecha_caducidad",
    "gravedad_efectos_secundarios",
    "estado_aprobación"
]

# %%
datos.sample(4)
# Out:
#     nombre_medicamento        fabricante  año_aprobación clase_medicamento  \
# 468       Fenoprofen78   GlaxoSmithKline            2015           Vaccine
# 63         Viraparin98  Roche Holding AG            2009       Antipyretic
# 616       Serodipine85       Novartis AG            2007     Antipsychotic
# 36        Mecodipine51       Pfizer Inc.            2003         Antiviral
#
#                indicaciones                efectos_secundarios  dosis_mg  \
# 468        Viral infections  Dizziness, Constipation, Headache        40
# 63   Inflammation reduction              Constipation, Fatigue       620
# 616             Pain relief       Nausea, Blurred vision, Rash       550
# 36           Allergy relief                           Insomnia       440
#
#     vía_administración contraindicaciones                 advertencias  \
# 468        Intravenous      Liver disease     Do not operate machinery
# 63         Intravenous           Seizures  Do not discontinue abruptly
# 616            Topical      Heart disease      Avoid sunlight exposure
# 36       Intramuscular           Seizures     Do not operate machinery
#
#      precio_usd número_lote fecha_caducidad gravedad_efectos_secundarios  \
# 468       20.11     wa399Tn      2027-01-18                         Mild
# 63       357.15     bb917Ce      2026-02-10                       Severe
# 616       87.31     eJ063Tr      2027-10-17                         Mild
# 36       466.79     HP064At      2027-08-04                     Moderate
#
#     estado_aprobación
# 468          Approved
# 63            Pending
# 616           Pending
# 36           Rejected

# %%
# exportar a csv

datos.to_csv('datos.csv')

# %%
# llamar la nueva base

data = pd.read_csv('/content/datos.csv')

# %%
data.sample(4)
# Out:
#       Unnamed: 0 nombre_medicamento         fabricante  año_aprobación  \
# 1370        1370         Cefparin24    GlaxoSmithKline            2011
# 1410        1410          Daxovir35        AstraZeneca            2001
# 899          899       Daxoxetine71  Johnson & Johnson            2001
# 1267        1267       Daxocillin84        AstraZeneca            1991
#
#       clase_medicamento       indicaciones          efectos_secundarios  \
# 1370  Anti-inflammatory  Fungal infections            Nausea, Dizziness
# 1410      Antipsychotic  Fungal infections   Nausea, Diarrhea, Headache
# 899         Antipyretic    Fever reduction  Diarrhea, Insomnia, Fatigue
# 1267  Anti-inflammatory  Fungal infections                         Rash
#
#       dosis_mg vía_administración  contraindicaciones  \
# 1370       920             Rectal       Heart disease
# 1410        90               Oral  Bleeding disorders
# 899        160         Sublingual              Asthma
# 1267       600         Inhalation       Heart disease
#
#                      advertencias  precio_usd número_lote fecha_caducidad  \
# 1370  Use with caution in elderly      455.54     kO529nn      2028-06-30
# 1410            Risk of addiction       85.14     ia005qN      2027-03-19
# 899        Monitor blood pressure      498.68     bL265hp      2028-02-09
# 1267  Use with caution in elderly      285.48     sW914TV      2027-08-26
#
#      gravedad_efectos_secundarios estado_aprobación
# 1370                       Severe          Approved
# 1410                       Severe          Rejected
# 899                      Moderate          Rejected
# 1267                     Moderate          Rejected

# %%
# eliminar una columna

data = data.drop('Unnamed: 0', axis=1)

# %%
data.sample(4)
# Out:
#      nombre_medicamento         fabricante  año_aprobación  clase_medicamento  \
# 1365       Fenoxetine11        Merck & Co.            1995      Antipsychotic
# 1000         Rivazole38        AstraZeneca            2002  Anti-inflammatory
# 172          Amoxzole12  Johnson & Johnson            1997          Antiviral
# 1259         Virazole38    GlaxoSmithKline            2002  Anti-inflammatory
#
#               indicaciones                efectos_secundarios  dosis_mg  \
# 1365  Depression treatment                               Rash       670
# 1000      Viral infections  Constipation, Dry mouth, Headache       820
# 172      Psychosis control        Insomnia, Nausea, Dry mouth       150
# 1259           Pain relief       Nausea, Blurred vision, Rash       970
#
#      vía_administración   contraindicaciones                 advertencias  \
# 1365      Intramuscular  High blood pressure  Do not discontinue abruptly
# 1000        Intravenous    Allergic reaction            Risk of addiction
# 172                Oral             Diabetes         May affect fertility
# 1259            Topical             Diabetes               Take with food
#
#       precio_usd número_lote fecha_caducidad gravedad_efectos_secundarios  \
# 1365      314.39     ic603oB      2026-07-15                       Severe
# 1000      203.78     iU259nf      2028-03-24                     Moderate
# 172       113.93     Pi951HS      2028-04-29                     Moderate
# 1259       58.89     jz375MU      2028-07-20                     Moderate
#
#      estado_aprobación
# 1365           Pending
# 1000          Approved
# 172            Pending
# 1259          Approved

# %%
data.dtypes
# Out:
# nombre_medicamento               object
# fabricante                       object
# año_aprobación                    int64
# clase_medicamento                object
# indicaciones                     object
# efectos_secundarios              object
# dosis_mg                          int64
# vía_administración               object
# contraindicaciones               object
# advertencias                     object
# precio_usd                      float64
# número_lote                      object
# fecha_caducidad                  object
# gravedad_efectos_secundarios     object
# estado_aprobación                object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   nombre_medicamento            1436 non-null   object
#  1   fabricante                    1436 non-null   object
#  2   año_aprobación                1436 non-null   int64
#  3   clase_medicamento             1436 non-null   object
#  4   indicaciones                  1436 non-null   object
#  5   efectos_secundarios           1436 non-null   object
#  6   dosis_mg                      1436 non-null   int64
#  7   vía_administración            1436 non-null   object
#  8   contraindicaciones            1436 non-null   object
#  9   advertencias                  1436 non-null   object
#  10  precio_usd                    1436 non-null   float64
#  11  número_lote                   1436 non-null   object
#  12  fecha_caducidad               1436 non-null   object
#  13  gravedad_efectos_secundarios  1436 non-null   object
#  14  estado_aprobación             1436 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 168.4+ KB

# %%
data.isnull().sum()
# Out:
# nombre_medicamento              0
# fabricante                      0
# año_aprobación                  0
# clase_medicamento               0
# indicaciones                    0
# efectos_secundarios             0
# dosis_mg                        0
# vía_administración              0
# contraindicaciones              0
# advertencias                    0
# precio_usd                      0
# número_lote                     0
# fecha_caducidad                 0
# gravedad_efectos_secundarios    0
# estado_aprobación               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#        año_aprobación     dosis_mg   precio_usd
# count     1436.000000  1436.000000  1436.000000
# mean      2006.860028   509.637883   251.844854
# std         10.167067   286.417268   142.640781
# min       1990.000000    10.000000     1.210000
# 25%       1998.000000   270.000000   128.830000
# 50%       2007.000000   515.000000   255.130000
# 75%       2016.000000   760.000000   372.207500
# max       2024.000000   990.000000   499.060000

# %% [markdown]
# #
#
# ---
# # <center><Font Color="#615FFF" size="8"> Preparando Datos</Font> </center>
# ---

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.16.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
# biblioteca

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from catboost import CatBoostClassifier

# %%
# hecer copia profunda del dataframe
import copy
datos_ml = copy.deepcopy(data)

# %%
# eliminar columnas

datos_ml = datos_ml.drop(columns=['número_lote', 'fecha_caducidad','nombre_medicamento'])

# %%
datos_ml.head(7)
# Out:
#           fabricante  año_aprobación  clase_medicamento  \
# 0        AstraZeneca            1996     Antidepressant
# 1        AstraZeneca            2018            Vaccine
# 2        Merck & Co.            1997      Antipsychotic
# 3   Roche Holding AG            2004         Antifungal
# 4        Pfizer Inc.            2003     Antidepressant
# 5  Johnson & Johnson            2023         Antifungal
# 6        AstraZeneca            2004  Anti-inflammatory
#
#              indicaciones                  efectos_secundarios  dosis_mg  \
# 0          Allergy relief                      Fatigue, Nausea       260
# 1          Allergy relief                               Nausea       470
# 2          Allergy relief  Diarrhea, Blurred vision, Dizziness       330
# 3  Inflammation reduction                   Fatigue, Dry mouth       450
# 4       Psychosis control         Insomnia, Dry mouth, Fatigue       430
# 5        Viral infections                      Rash, Dizziness       180
# 6       Psychosis control                       Blurred vision       500
#
#   vía_administración   contraindicaciones              advertencias  \
# 0             Rectal   Bleeding disorders             Avoid alcohol
# 1         Inhalation    Allergic reaction            Take with food
# 2         Sublingual  High blood pressure            Take with food
# 3               Oral    Kidney impairment  Do not operate machinery
# 4            Topical   Bleeding disorders  Do not operate machinery
# 5        Intravenous   Bleeding disorders      May affect fertility
# 6            Topical   Bleeding disorders      May affect fertility
#
#    precio_usd gravedad_efectos_secundarios estado_aprobación
# 0      192.43                         Mild           Pending
# 1      397.82                         Mild          Approved
# 2      131.69                     Moderate           Pending
# 3      372.82                         Mild          Rejected
# 4      281.48                     Moderate           Pending
# 5      463.28                     Moderate          Rejected
# 6      320.77                         Mild           Pending

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(datos_ml['estado_aprobación'])

# %%
datos_ml['estado_aprobación'].value_counts()
# Out:
# estado_aprobación
# Pending     496
# Rejected    478
# Approved    462
# Name: count, dtype: int64

# %%
datos_ml['estado_aprobación'].value_counts()
# Out:
# estado_aprobación
# Pending     496
# Rejected    478
# Approved    462
# Name: count, dtype: int64

# %%
datos_ml['fabricante'].value_counts()
# Out:
# fabricante
# Merck & Co.             157
# Johnson & Johnson       149
# Sanofi                  148
# Bayer AG                147
# Moderna Therapeutics    146
# Novartis AG             144
# GlaxoSmithKline         140
# Roche Holding AG        137
# Pfizer Inc.             136
# AstraZeneca             132
# Name: count, dtype: int64

# %%
top_fabricantes = ['Merck & Co.', 'Johnson & Johnson', 'Sanofi', 'Bayer AG',
                  'Moderna Therapeutics', 'Novartis AG', 'GlaxoSmithKline',
                  'Roche Holding AG', 'Pfizer Inc.', 'AstraZeneca']

# Agrupar fabricantes fuera del top 10 en 'Otros'
datos_ml['fabricante'] = datos_ml['fabricante'].apply(lambda x: x if x in top_fabricantes else 'Otros')

# %%
datos_ml['clase_medicamento'].value_counts()
# Out:
# clase_medicamento
# Anti-inflammatory    158
# Antidepressant       156
# Antipsychotic        147
# Vaccine              144
# Antifungal           144
# Antibiotic           143
# Antihistamine        143
# Antiviral            141
# Antipyretic          134
# Analgesic            126
# Name: count, dtype: int64

# %%
top_clases = ['Anti-inflammatory', 'Antidepressant', 'Antipsychotic', 'Vaccine',
              'Antifungal', 'Antibiotic', 'Antihistamine', 'Antiviral',
              'Antipyretic', 'Analgesic']

datos_ml['clase_medicamento'] = datos_ml['clase_medicamento'].apply(lambda x: x if x in top_clases else 'Otros')

# %%
# variables para machine

X = datos_ml.drop(columns=['estado_aprobación'])
y = datos_ml['estado_aprobación']

# %%
mapping = {'Rejected': 0, 'Pending': 1, 'Approved': 2}
datos_ml['estado_aprobación'] = datos_ml['estado_aprobación'].map(mapping)

# %%
datos_ml.head(3)
# Out:
#     fabricante  año_aprobación clase_medicamento    indicaciones  \
# 0  AstraZeneca            1996    Antidepressant  Allergy relief
# 1  AstraZeneca            2018           Vaccine  Allergy relief
# 2  Merck & Co.            1997     Antipsychotic  Allergy relief
#
#                    efectos_secundarios  dosis_mg vía_administración  \
# 0                      Fatigue, Nausea       260             Rectal
# 1                               Nausea       470         Inhalation
# 2  Diarrhea, Blurred vision, Dizziness       330         Sublingual
#
#     contraindicaciones    advertencias  precio_usd  \
# 0   Bleeding disorders   Avoid alcohol      192.43
# 1    Allergic reaction  Take with food      397.82
# 2  High blood pressure  Take with food      131.69
#
#   gravedad_efectos_secundarios  estado_aprobación
# 0                         Mild                  1
# 1                         Mild                  2
# 2                     Moderate                  1

# %%
#X = pd.get_dummies(X)

# %%
# dividir la prueba
X,X_test,y,y_test = train_test_split(X,y,test_size=0.15,stratify=y,random_state=42)
X_train,X_val,y_train,y_val = train_test_split(X,y,stratify=y,random_state=5)

# %%
modelo = CatBoostClassifier(
    iterations=500,
    depth=8,
    learning_rate=0.05,
    loss_function='MultiClass',
    random_seed=42,
    verbose=100
)
modelo.fit(X_train, y_train, cat_features=cat_features)
y_pred = modelo.predict(X_test)
print(f'La precisión del modelo train es de : {modelo.score(X_train, y_train) * 100:.2f}%')
print(f'La precisión del modelo de validación es de : {modelo.score(X_val, y_val) * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3647662239.py in <cell line: 0>()
#       7     verbose=100
#       8 )
# ----> 9 modelo.fit(X_train, y_train, cat_features=cat_features)
#      10 y_pred = modelo.predict(X_test)
#      11 print(f'La precisión del modelo train es de : {modelo.score(X_train, y_train) * 100:.2f}%')
#
# NameError: name 'cat_features' is not defined

# %%
y_pred = modelo.predict(X_test)

# %%
# Evaluación
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nReporte de Clasificación:\n", classification_report(y_test, y_pred))
print("\nMatriz de Confusión:\n", confusion_matrix(y_test, y_pred))
