# %% [markdown]
# <a href="https://colab.research.google.com/github/r2x4/aprendiendo_machine/blob/main/machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
#
# ----
# # <center><font color="#615FFF" size="8"> Practice Machine Learning </font></center>
# ----

# %%
# llamar datos
import pandas as pd

datos = pd.read_csv('/content/realistic_drug_labels_side_effects.csv')

# %%
datos.shape
# Out:
# (1436, 15)

# %%
datos.sample(4)
# Out:
#          drug_name     manufacturer  approval_year     drug_class  \
# 1039     Amoxvir17         Bayer AG           1999  Antipsychotic
# 1305    Cefzepam61  GlaxoSmithKline           2006  Antipsychotic
# 285   Mecocillin79  GlaxoSmithKline           1991    Antipyretic
# 95     Zyloparin24      AstraZeneca           2015      Antiviral
#
#                      indications          side_effects  dosage_mg  \
# 1039            Viral infections       Rash, Dizziness        950
# 1305  Prevent infectious disease  Nausea, Constipation        320
# 285            Fungal infections          Constipation        880
# 95          Depression treatment   Dizziness, Insomnia        240
#
#      administration_route   contraindications                     warnings  \
# 1039           Inhalation  Bleeding disorders  Do not discontinue abruptly
# 1305           Sublingual   Allergic reaction     Do not operate machinery
# 285               Topical   Allergic reaction     Do not operate machinery
# 95                Topical           Pregnancy         May cause drowsiness
#
#       price_usd batch_number expiry_date side_effect_severity approval_status
# 1039     139.14      Dr617rG  2026-07-29               Severe         Pending
# 1305     120.30      FB213tW  2027-08-02                 Mild        Rejected
# 285      100.28      vb849bC  2026-07-24             Moderate        Rejected
# 95       440.99      ed189sM  2027-03-04               Severe         Pending

# %%
datos.columns
# Out:
# Index(['drug_name', 'manufacturer', 'approval_year', 'drug_class',
#        'indications', 'side_effects', 'dosage_mg', 'administration_route',
#        'contraindications', 'warnings', 'price_usd', 'batch_number',
#        'expiry_date', 'side_effect_severity', 'approval_status'],
#       dtype='object')

# %%
# renombrar la columnas

datos.columns = [
    "nombre_medicamento",
    "fabricante",
    "año_aprobación",
    "clase_medicamento",
    "indicaciones",
    "efectos_secundarios",
    "dosis_mg",
    "vía_administración",
    "contraindicaciones",
    "advertencias",
    "precio_usd",
    "número_lote",
    "fecha_caducidad",
    "gravedad_efectos_secundarios",
    "estado_aprobación"
]

# %%
datos.sample(4)
# Out:
#      nombre_medicamento            fabricante  año_aprobación  \
# 344           Zylovir94  Moderna Therapeutics            2016
# 619          Cefzepam49     Johnson & Johnson            2005
# 8            Cefparin42                Sanofi            2012
# 1032          Serovir13           AstraZeneca            2017
#
#       clase_medicamento                indicaciones efectos_secundarios  \
# 344   Anti-inflammatory  Prevent infectious disease            Insomnia
# 619   Anti-inflammatory        Depression treatment  Headache, Insomnia
# 8             Analgesic  Prevent infectious disease           Dry mouth
# 1032         Antifungal           Fungal infections     Rash, Dizziness
#
#       dosis_mg vía_administración  contraindicaciones  \
# 344        300      Intramuscular  Bleeding disorders
# 619         80         Inhalation           Pregnancy
# 8          420               Oral              Asthma
# 1032       540         Inhalation  Bleeding disorders
#
#                  advertencias  precio_usd número_lote fecha_caducidad  \
# 344   Avoid sunlight exposure      272.82     kD883LK      2028-07-14
# 619         Risk of addiction      434.45     kq560RS      2026-12-22
# 8               Avoid alcohol      251.97     TU342KC      2026-10-04
# 1032           Take with food      242.30     Zm132Qk      2028-01-04
#
#      gravedad_efectos_secundarios estado_aprobación
# 344                          Mild          Approved
# 619                        Severe          Approved
# 8                        Moderate          Approved
# 1032                       Severe           Pending

# %%
# exportar a csv

datos.to_csv('datos.csv')

# %%
# llamar la nueva base

data = pd.read_csv('/content/datos.csv')

# %%
data.sample(4)
# Out:
#       Unnamed: 0 nombre_medicamento         fabricante  año_aprobación  \
# 557          557       Fenodipine80  Johnson & Johnson            2010
# 1431        1431         Mecozole92        Pfizer Inc.            1993
# 1278        1278       Rivadipine74        Novartis AG            1991
# 632          632       Viraprofen38        Novartis AG            1990
#
#      clase_medicamento            indicaciones efectos_secundarios  dosis_mg  \
# 557     Antidepressant  Inflammation reduction           Dry mouth       120
# 1431     Antihistamine       Fungal infections           Dry mouth       850
# 1278           Vaccine  Inflammation reduction      Blurred vision       300
# 632            Vaccine       Psychosis control             Fatigue        60
#
#      vía_administración   contraindicaciones                 advertencias  \
# 557                Oral  High blood pressure         May cause drowsiness
# 1431         Inhalation        Liver disease         May affect fertility
# 1278      Intramuscular             Diabetes  Do not discontinue abruptly
# 632              Rectal               Asthma      Avoid sunlight exposure
#
#       precio_usd número_lote fecha_caducidad gravedad_efectos_secundarios  \
# 557       344.68     IJ182ls      2028-03-20                     Moderate
# 1431       47.48     Kv961uR      2026-01-20                     Moderate
# 1278      387.90     Jd124PA      2026-07-18                     Moderate
# 632       415.27     Pl354gb      2027-07-17                       Severe
#
#      estado_aprobación
# 557            Pending
# 1431          Rejected
# 1278          Rejected
# 632           Rejected

# %%
# eliminar una columna

data = data.drop('Unnamed: 0', axis=1)

# %%
data.sample(4)
# Out:
#      nombre_medicamento       fabricante  año_aprobación clase_medicamento  \
# 193          Cefzepam59         Bayer AG            2006           Vaccine
# 278         Virazepam11      Merck & Co.            2022           Vaccine
# 772        Rivadipine71  GlaxoSmithKline            2000        Antibiotic
# 1275       Rivacillin44  GlaxoSmithKline            2009    Antidepressant
#
#                 indicaciones          efectos_secundarios  dosis_mg  \
# 193         Viral infections                      Fatigue       930
# 278   Inflammation reduction  Fatigue, Constipation, Rash       720
# 772   Inflammation reduction                      Fatigue       690
# 1275         Fever reduction   Headache, Insomnia, Nausea       400
#
#      vía_administración contraindicaciones       advertencias  precio_usd  \
# 193                Oral             Asthma     Take with food      148.53
# 278          Inhalation      Heart disease  Risk of addiction      439.64
# 772             Topical  Kidney impairment  Risk of addiction      450.93
# 1275         Inhalation      Heart disease     Take with food      433.02
#
#      número_lote fecha_caducidad gravedad_efectos_secundarios  \
# 193      tM606xZ      2028-03-04                         Mild
# 278      jo025ON      2026-10-01                     Moderate
# 772      wI853QP      2025-12-25                         Mild
# 1275     Pz575JJ      2026-11-02                         Mild
#
#      estado_aprobación
# 193            Pending
# 278           Rejected
# 772            Pending
# 1275           Pending

# %%
data.dtypes
# Out:
# nombre_medicamento               object
# fabricante                       object
# año_aprobación                    int64
# clase_medicamento                object
# indicaciones                     object
# efectos_secundarios              object
# dosis_mg                          int64
# vía_administración               object
# contraindicaciones               object
# advertencias                     object
# precio_usd                      float64
# número_lote                      object
# fecha_caducidad                  object
# gravedad_efectos_secundarios     object
# estado_aprobación                object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   nombre_medicamento            1436 non-null   object
#  1   fabricante                    1436 non-null   object
#  2   año_aprobación                1436 non-null   int64
#  3   clase_medicamento             1436 non-null   object
#  4   indicaciones                  1436 non-null   object
#  5   efectos_secundarios           1436 non-null   object
#  6   dosis_mg                      1436 non-null   int64
#  7   vía_administración            1436 non-null   object
#  8   contraindicaciones            1436 non-null   object
#  9   advertencias                  1436 non-null   object
#  10  precio_usd                    1436 non-null   float64
#  11  número_lote                   1436 non-null   object
#  12  fecha_caducidad               1436 non-null   object
#  13  gravedad_efectos_secundarios  1436 non-null   object
#  14  estado_aprobación             1436 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 168.4+ KB

# %%
data.isnull().sum()
# Out:
# nombre_medicamento              0
# fabricante                      0
# año_aprobación                  0
# clase_medicamento               0
# indicaciones                    0
# efectos_secundarios             0
# dosis_mg                        0
# vía_administración              0
# contraindicaciones              0
# advertencias                    0
# precio_usd                      0
# número_lote                     0
# fecha_caducidad                 0
# gravedad_efectos_secundarios    0
# estado_aprobación               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#        año_aprobación     dosis_mg   precio_usd
# count     1436.000000  1436.000000  1436.000000
# mean      2006.860028   509.637883   251.844854
# std         10.167067   286.417268   142.640781
# min       1990.000000    10.000000     1.210000
# 25%       1998.000000   270.000000   128.830000
# 50%       2007.000000   515.000000   255.130000
# 75%       2016.000000   760.000000   372.207500
# max       2024.000000   990.000000   499.060000

# %% [markdown]
# #
#
# ---
# # <center><Font Color="#615FFF" size="8"> Preparando Datos</Font> </center>
# ---

# %%
# biblioteca

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from catboost import CatBoostClassifier

# %%
# hecer copia profunda del dataframe
import copy
datos_ml = copy.deepcopy(data)

# %%
# eliminar columnas

datos_ml = datos_ml.drop(columns=['número_lote', 'fecha_caducidad'])

# %%
datos_ml.head(7)
# Out:
#   nombre_medicamento         fabricante  año_aprobación  clase_medicamento  \
# 0       Seroxetine50        AstraZeneca            1996     Antidepressant
# 1        Mecoparin93        AstraZeneca            2018            Vaccine
# 2         Daxozole89        Merck & Co.            1997      Antipsychotic
# 3       Viracillin84   Roche Holding AG            2004         Antifungal
# 4       Amoxstatin62        Pfizer Inc.            2003     Antidepressant
# 5       Loxocillin72  Johnson & Johnson            2023         Antifungal
# 6       Fenoxetine43        AstraZeneca            2004  Anti-inflammatory
#
#              indicaciones                  efectos_secundarios  dosis_mg  \
# 0          Allergy relief                      Fatigue, Nausea       260
# 1          Allergy relief                               Nausea       470
# 2          Allergy relief  Diarrhea, Blurred vision, Dizziness       330
# 3  Inflammation reduction                   Fatigue, Dry mouth       450
# 4       Psychosis control         Insomnia, Dry mouth, Fatigue       430
# 5        Viral infections                      Rash, Dizziness       180
# 6       Psychosis control                       Blurred vision       500
#
#   vía_administración   contraindicaciones              advertencias  \
# 0             Rectal   Bleeding disorders             Avoid alcohol
# 1         Inhalation    Allergic reaction            Take with food
# 2         Sublingual  High blood pressure            Take with food
# 3               Oral    Kidney impairment  Do not operate machinery
# 4            Topical   Bleeding disorders  Do not operate machinery
# 5        Intravenous   Bleeding disorders      May affect fertility
# 6            Topical   Bleeding disorders      May affect fertility
#
#    precio_usd gravedad_efectos_secundarios estado_aprobación
# 0      192.43                         Mild           Pending
# 1      397.82                         Mild          Approved
# 2      131.69                     Moderate           Pending
# 3      372.82                         Mild          Rejected
# 4      281.48                     Moderate           Pending
# 5      463.28                     Moderate          Rejected
# 6      320.77                         Mild           Pending

# %%
# variables para machine

X = datos_ml.drop(columns=['estado_aprobación'])
y = datos_ml['estado_aprobación']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(datos_ml['estado_aprobación'])

# %%
datos_ml['estado_aprobación'].value_counts()
# Out:
# estado_aprobación
# Pending     496
# Rejected    478
# Approved    462
# Name: count, dtype: int64

# %%
mapping = {'Rejected': 0, 'Pending': 1, 'Approved': 2}
datos_ml['estado_aprobación'] = datos_ml['estado_aprobación'].map(mapping)

# %%
datos_ml.head(3)
# Out:
#   nombre_medicamento   fabricante  año_aprobación clase_medicamento  \
# 0       Seroxetine50  AstraZeneca            1996    Antidepressant
# 1        Mecoparin93  AstraZeneca            2018           Vaccine
# 2         Daxozole89  Merck & Co.            1997     Antipsychotic
#
#      indicaciones                  efectos_secundarios  dosis_mg  \
# 0  Allergy relief                      Fatigue, Nausea       260
# 1  Allergy relief                               Nausea       470
# 2  Allergy relief  Diarrhea, Blurred vision, Dizziness       330
#
#   vía_administración   contraindicaciones    advertencias  precio_usd  \
# 0             Rectal   Bleeding disorders   Avoid alcohol      192.43
# 1         Inhalation    Allergic reaction  Take with food      397.82
# 2         Sublingual  High blood pressure  Take with food      131.69
#
#   gravedad_efectos_secundarios  estado_aprobación
# 0                         Mild                  1
# 1                         Mild                  2
# 2                     Moderate                  1

# %%
#X = pd.get_dummies(X)

# %%
# dividir la prueba
X,X_test,y,y_test = train_test_split(X,y,test_size=0.15,stratify=y,random_state=42)
X_train,X_val,y_train,y_val = train_test_split(X,y,stratify=y,random_state=5)

# %%
modelo = CatBoostClassifier(
    iterations=500,
    depth=8,
    learning_rate=0.05,
    loss_function='MultiClass',
    random_seed=42,
    verbose=100
)
modelo.fit(X_train, y_train, cat_features=cat_features)
y_pred = modelo.predict(X_test)
print(f'La precisión del modelo train es de : {modelo.score(X_train, y_train) * 100:.2f}%')
print(f'La precisión del modelo de validación es de : {modelo.score(X_val, y_val) * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3647662239.py in <cell line: 0>()
#       7     verbose=100
#       8 )
# ----> 9 modelo.fit(X_train, y_train, cat_features=cat_features)
#      10 y_pred = modelo.predict(X_test)
#      11 print(f'La precisión del modelo train es de : {modelo.score(X_train, y_train) * 100:.2f}%')
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5243             CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
#    5244
# -> 5245         self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#    5246                   eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5247                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2393                 raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
#    2394
# -> 2395             train_params = self._prepare_train_params(
#    2396                 X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    2397                 pairs=pairs, graph=graph, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in _prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    2273         embedding_features = _process_feature_indices(embedding_features, X, params, 'embedding_features')
#    2274
# -> 2275         train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, graph,
#    2276                                        sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
#    2277                                        baseline, column_description)
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1511         if y is None:
#    1512             raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
# -> 1513         train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, graph=graph, weight=sample_weight, group_id=group_id,
#    1514                           group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    1515     return train_pool
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, graph, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr, data_can_be_none)
#     853                         )
#     854
# --> 855                     self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight,
#     856                                group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     857             elif not data_can_be_none:
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in _init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1436             self._check_feature_names(feature_names, features_count)
#    1437         if cat_features is not None:
# -> 1438             cat_features = _get_features_indices(cat_features, feature_names)
#    1439             self._check_string_feature_type(cat_features, 'cat_features')
#    1440             self._check_string_feature_value(cat_features, features_count, 'cat_features')
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in _get_features_indices(features, feature_names)
#     316         raise CatBoostError("feature names should be a sequence, but got " + repr(features))
#     317     if feature_names is not None:
# --> 318         return [
#     319             feature_names.index(f) if isinstance(f, STRING_TYPES) else f
#     320             for f in features
#
# /usr/local/lib/python3.11/dist-packages/catboost/core.py in <listcomp>(.0)
#     317     if feature_names is not None:
#     318         return [
# --> 319             feature_names.index(f) if isinstance(f, STRING_TYPES) else f
#     320             for f in features
#     321         ]
#
# ValueError: 'estado_aprobación' is not in list

# %%
y_pred = modelo.predict(X_test)

# %%
# Evaluación
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nReporte de Clasificación:\n", classification_report(y_test, y_pred))
print("\nMatriz de Confusión:\n", confusion_matrix(y_test, y_pred))
