# %% [markdown]
# <a href="https://colab.research.google.com/github/r2x4/aprendiendo_machine/blob/main/machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
#
# ----
# # <center><font color="#615FFF" size="8"> Practice Machine Learning </font></center>
# ----

# %%
# llamar datos
import pandas as pd

datos = pd.read_csv('/content/realistic_drug_labels_side_effects.csv')

# %%
datos.shape
# Out:
# (1436, 15)

# %%
datos.sample(4)
# Out:
#         drug_name          manufacturer  approval_year      drug_class  \
# 43      Amoxvir70      Roche Holding AG           2024   Antipsychotic
# 437    Amoxzole56  Moderna Therapeutics           2022  Antidepressant
# 140  Rivaxetine79                Sanofi           2010      Antibiotic
# 827     Zylomab50                Sanofi           2010       Antiviral
#
#               indications                 side_effects  dosage_mg  \
# 43       Viral infections  Dizziness, Headache, Nausea        410
# 437       Fever reduction                 Constipation        470
# 140  Bacterial infections            Fatigue, Headache        930
# 827           Pain relief               Blurred vision        870
#
#     administration_route  contraindications                     warnings  \
# 43           Intravenous             Asthma               Take with food
# 437        Intramuscular  Kidney impairment            Risk of addiction
# 140              Topical           Diabetes  Do not discontinue abruptly
# 827          Intravenous  Allergic reaction     Do not operate machinery
#
#      price_usd batch_number expiry_date side_effect_severity approval_status
# 43      479.84      Wq735lJ  2028-06-02               Severe         Pending
# 437      63.77      sQ859Fg  2026-07-18               Severe        Rejected
# 140      12.18      PN330DB  2027-11-14                 Mild        Rejected
# 827     158.54      Qi786gz  2028-02-17             Moderate         Pending

# %%
datos.columns
# Out:
# Index(['drug_name', 'manufacturer', 'approval_year', 'drug_class',
#        'indications', 'side_effects', 'dosage_mg', 'administration_route',
#        'contraindications', 'warnings', 'price_usd', 'batch_number',
#        'expiry_date', 'side_effect_severity', 'approval_status'],
#       dtype='object')

# %%
# renombrar la columnas

datos.columns = [
    "nombre_medicamento",
    "fabricante",
    "año_aprobación",
    "clase_medicamento",
    "indicaciones",
    "efectos_secundarios",
    "dosis_mg",
    "vía_administración",
    "contraindicaciones",
    "advertencias",
    "precio_usd",
    "número_lote",
    "fecha_caducidad",
    "gravedad_efectos_secundarios",
    "estado_aprobación"
]

# %%
datos.sample(4)
# Out:
#     nombre_medicamento         fabricante  año_aprobación  clase_medicamento  \
# 783        Zylozepam80  Johnson & Johnson            1997         Antifungal
# 791          Daxomab18  Johnson & Johnson            1999  Anti-inflammatory
# 423        Daxozepam65        AstraZeneca            1993         Antifungal
# 43           Amoxvir70   Roche Holding AG            2024      Antipsychotic
#
#              indicaciones           efectos_secundarios  dosis_mg  \
# 783     Psychosis control  Insomnia, Rash, Constipation       580
# 791  Bacterial infections                      Diarrhea       740
# 423       Fever reduction           Dry mouth, Insomnia       940
# 43       Viral infections   Dizziness, Headache, Nausea       410
#
#     vía_administración contraindicaciones                 advertencias  \
# 783         Sublingual           Seizures         May affect fertility
# 791        Intravenous      Liver disease  Do not discontinue abruptly
# 423      Intramuscular      Liver disease         May affect fertility
# 43         Intravenous             Asthma               Take with food
#
#      precio_usd número_lote fecha_caducidad gravedad_efectos_secundarios  \
# 783      340.04     VZ878Jw      2028-07-08                     Moderate
# 791      155.10     jN609DO      2028-02-17                       Severe
# 423      389.03     yW717ju      2027-06-22                         Mild
# 43       479.84     Wq735lJ      2028-06-02                       Severe
#
#     estado_aprobación
# 783          Approved
# 791           Pending
# 423          Rejected
# 43            Pending

# %%
# exportar a csv

datos.to_csv('datos.csv')

# %%
# llamar la nueva base

data = pd.read_csv('/content/datos.csv')

# %%
data.sample(4)
# Out:
#       Unnamed: 0 nombre_medicamento            fabricante  año_aprobación  \
# 610          610          Mecomab24              Bayer AG            2024
# 1008        1008          Amoxmab35  Moderna Therapeutics            2002
# 1047        1047       Rivadipine80       GlaxoSmithKline            2019
# 891          891        Daxoparin77                Sanofi            2003
#
#      clase_medicamento          indicaciones  \
# 610          Antiviral  Bacterial infections
# 1008     Antihistamine      Viral infections
# 1047    Antidepressant     Fungal infections
# 891          Analgesic        Allergy relief
#
#                       efectos_secundarios  dosis_mg vía_administración  \
# 610                      Headache, Nausea       560               Oral
# 1008                         Constipation       620         Inhalation
# 1047              Rash, Diarrhea, Fatigue       130      Intramuscular
# 891   Blurred vision, Dizziness, Headache       460      Intramuscular
#
#        contraindicaciones             advertencias  precio_usd número_lote  \
# 610   High blood pressure            Avoid alcohol       26.89     Zd088Tb
# 1008        Heart disease     May cause drowsiness      307.14     sf588CC
# 1047        Heart disease  Avoid sunlight exposure      134.20     tq598Hq
# 891              Seizures     May affect fertility      292.87     wZ490Qa
#
#      fecha_caducidad gravedad_efectos_secundarios estado_aprobación
# 610       2026-07-01                     Moderate          Approved
# 1008      2028-03-07                     Moderate           Pending
# 1047      2027-08-17                     Moderate          Rejected
# 891       2027-10-25                       Severe          Approved

# %%
# eliminar una columna

data = data.drop('Unnamed: 0', axis=1)

# %%
data.sample(4)
# Out:
#      nombre_medicamento            fabricante  año_aprobación  \
# 1316       Fenocillin92  Moderna Therapeutics            2013
# 992          Fenozole66           Merck & Co.            1997
# 78            Zylovir64       GlaxoSmithKline            2008
# 1249       Rivaxetine31           Novartis AG            2013
#
#       clase_medicamento            indicaciones  \
# 1316  Anti-inflammatory       Fungal infections
# 992         Antipyretic  Inflammation reduction
# 78            Antiviral    Bacterial infections
# 1249          Antiviral       Fungal infections
#
#                      efectos_secundarios  dosis_mg vía_administración  \
# 1316              Headache, Constipation       320      Intramuscular
# 992   Blurred vision, Insomnia, Headache       650        Intravenous
# 78    Dry mouth, Fatigue, Blurred vision        20            Topical
# 1249                 Headache, Dry mouth       500             Rectal
#
#       contraindicaciones             advertencias  precio_usd número_lote  \
# 1316  Bleeding disorders     May cause drowsiness      242.21     zC841Bk
# 992        Heart disease           Take with food      421.60     IA182eS
# 78             Pregnancy        Risk of addiction      333.46     RR246xi
# 1249       Heart disease  Avoid sunlight exposure      390.87     xJ067Qb
#
#      fecha_caducidad gravedad_efectos_secundarios estado_aprobación
# 1316      2026-09-29                     Moderate          Approved
# 992       2027-10-10                         Mild          Rejected
# 78        2027-07-21                         Mild          Rejected
# 1249      2028-07-28                       Severe          Approved

# %%
data.dtypes
# Out:
# nombre_medicamento               object
# fabricante                       object
# año_aprobación                    int64
# clase_medicamento                object
# indicaciones                     object
# efectos_secundarios              object
# dosis_mg                          int64
# vía_administración               object
# contraindicaciones               object
# advertencias                     object
# precio_usd                      float64
# número_lote                      object
# fecha_caducidad                  object
# gravedad_efectos_secundarios     object
# estado_aprobación                object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   nombre_medicamento            1436 non-null   object
#  1   fabricante                    1436 non-null   object
#  2   año_aprobación                1436 non-null   int64
#  3   clase_medicamento             1436 non-null   object
#  4   indicaciones                  1436 non-null   object
#  5   efectos_secundarios           1436 non-null   object
#  6   dosis_mg                      1436 non-null   int64
#  7   vía_administración            1436 non-null   object
#  8   contraindicaciones            1436 non-null   object
#  9   advertencias                  1436 non-null   object
#  10  precio_usd                    1436 non-null   float64
#  11  número_lote                   1436 non-null   object
#  12  fecha_caducidad               1436 non-null   object
#  13  gravedad_efectos_secundarios  1436 non-null   object
#  14  estado_aprobación             1436 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 168.4+ KB

# %%
data.isnull().sum()
# Out:
# nombre_medicamento              0
# fabricante                      0
# año_aprobación                  0
# clase_medicamento               0
# indicaciones                    0
# efectos_secundarios             0
# dosis_mg                        0
# vía_administración              0
# contraindicaciones              0
# advertencias                    0
# precio_usd                      0
# número_lote                     0
# fecha_caducidad                 0
# gravedad_efectos_secundarios    0
# estado_aprobación               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#        año_aprobación     dosis_mg   precio_usd
# count     1436.000000  1436.000000  1436.000000
# mean      2006.860028   509.637883   251.844854
# std         10.167067   286.417268   142.640781
# min       1990.000000    10.000000     1.210000
# 25%       1998.000000   270.000000   128.830000
# 50%       2007.000000   515.000000   255.130000
# 75%       2016.000000   760.000000   372.207500
# max       2024.000000   990.000000   499.060000
